# %%
import numpy as numpy
import pandas as pd
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

train_tr = pd.read_csv("train_transaction.csv")
test_tr = pd.read_csv("test_transaction.csv")
train_id = pd.read_csv("train_identity.csv")
test_id = pd.read_csv("test_identity.csv")

#missing value
print(train_tr.isnull().sum())
print("Train transaction: no missing value\n")
print(test_tr.isnull().sum())
print("Test transaction: no missing value\n")
print(train_id.isnull().sum())
print("Train Identity: no missing value\n")
print(test_id.isnull().sum())
print("Test Identity: no missing value\n")

#categorical value
print(train_tr.info())
print("Train transaction: no categorical value\n")
print(testn_tr.info())
print("Test transaction: no categorical value\n")
print(train_id.info())
print("Train Identity: no categorical value\n")
print(test_id.info())
print("Test Identity: no categorical value\n")
